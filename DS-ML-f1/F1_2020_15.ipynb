# %%
# initial run through of project

# %%
# import necessary libraries

import pandas as pd

# %%
# scraping data 

titles = ['practice-1', 'practice-2', 'practice-3', 'qualifying', 'race-result']
url = 'https://www.formula1.com/en/results.html/2020/races/1059/bahrain/{}.html'

for title in titles:
    urls = url.format(title)
    print(urls)
# Out:
# https://www.formula1.com/en/results.html/2020/races/1059/bahrain/practice-1.html
# https://www.formula1.com/en/results.html/2020/races/1059/bahrain/practice-2.html
# https://www.formula1.com/en/results.html/2020/races/1059/bahrain/practice-3.html
# https://www.formula1.com/en/results.html/2020/races/1059/bahrain/qualifying.html
# https://www.formula1.com/en/results.html/2020/races/1059/bahrain/race-result.html

# %%
FifteenP1_2020 ='https://www.formula1.com/en/results.html/2020/races/1059/bahrain/practice-1.html'
FifteenP2_2020 ='https://www.formula1.com/en/results.html/2020/races/1059/bahrain/practice-2.html'
FifteenP3_2020 ='https://www.formula1.com/en/results.html/2020/races/1059/bahrain/practice-3.html'
FifteenQ_2020 ='https://www.formula1.com/en/results.html/2020/races/1059/bahrain/qualifying.html'
FifteenRR_2020 ='https://www.formula1.com/en/results.html/2020/races/1059/bahrain/race-result.html'

# %%
df_FifteenP1_2020 = pd.read_html(FifteenP1_2020, header=0)
df_FifteenP2_2020 = pd.read_html(FifteenP2_2020, header=0)
df_FifteenP3_2020 = pd.read_html(FifteenP3_2020, header=0)
df_FifteenQ_2020 = pd.read_html(FifteenQ_2020, header=0)
df_FifteenRR_2020 = pd.read_html(FifteenRR_2020, header=0)

df_FifteenP1_2020 = df_FifteenP1_2020[0]
df_FifteenP2_2020 = df_FifteenP2_2020[0]
df_FifteenP3_2020 = df_FifteenP3_2020[0]
df_FifteenQ_2020 = df_FifteenQ_2020[0]
df_FifteenRR_2020 = df_FifteenRR_2020[0]

# %%
df_FifteenP1_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_FifteenP2_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_FifteenP3_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_FifteenQ_2020.drop(['Unnamed: 0', 'Unnamed: 9', 'No'], axis=1, inplace=True)
df_FifteenRR_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)

# %%
# df_FifteenP1_2020 = df_FifteenP1_2020.fillna(0)
# df_FifteenP2_2020 = df_FifteenP2_2020.fillna(0)
# df_FifteenP3_2020 = df_FifteenP3_2020.fillna(0)

# %%
bahrain_GP = [df_FifteenP1_2020, df_FifteenP2_2020, df_FifteenP3_2020, df_FifteenQ_2020, df_FifteenRR_2020]

# %%
bahrain_GP_0 = bahrain_GP[0]
bahrain_GP_1 = bahrain_GP[1]
bahrain_GP_2 = bahrain_GP[2]
bahrain_GP_3 = bahrain_GP[3]
bahrain_GP_4 = bahrain_GP[4]

# %%
bahrain_allP = pd.concat([bahrain_GP_0, bahrain_GP_1, bahrain_GP_2])
bahrain_allP = bahrain_allP.groupby('Driver').Pos.sum()
bahrain_allP = pd.DataFrame(bahrain_allP)
bahrain_allP.rename(columns = {'Pos': 'Pos_Practice'}, inplace = True)

# %%
bahrainQ = bahrain_GP_3.groupby('Driver').Pos.sum()
bahrainQ = pd.DataFrame(bahrainQ)
bahrainQ.rename(columns = {'Pos': 'Pos_Qualifying'}, inplace = True)

# %%
bahrainR = bahrain_GP_4.groupby('Driver').Pos.sum()
bahrainR = pd.DataFrame(bahrainR)
bahrainR.rename(columns = {'Pos': 'Pos_Race'}, inplace = True)

# %%
bahrain_end = pd.concat([bahrain_allP, bahrainQ, bahrainR], axis=1)

# %%
bahrain_GP_0.sort_values(by=['Driver'], inplace=True)
bahrain_GP_1.sort_values(by=['Driver'], inplace=True)
bahrain_GP_2.sort_values(by=['Driver'], inplace=True)
bahrain_GP_3.sort_values(by=['Driver'], inplace=True)
bahrain_GP_4.sort_values(by=['Driver'], inplace=True)

# %%
bahrain_dl = pd.merge(bahrain_GP_0, bahrain_GP_1, on='Driver', how='outer')
bahrain_dl = pd.merge(bahrain_dl, bahrain_GP_2, on='Driver', how='outer')
bahrain_dl = pd.merge(bahrain_dl, bahrain_GP_3, on='Driver', how='outer')
bahrain_dl = pd.merge(bahrain_dl, bahrain_GP_4, on='Driver', how='outer')

# %%
change_dups = bahrain_dl.columns.values.tolist()
change_dups
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x',
#  'Car_x',
#  'Time',
#  'Gap',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
def uniquify(change_dups):
    seen = set()
    
    for dup in change_dups:
        name = 1
        new_name = dup
        
        while new_name in seen:
            name += 1
            new_name = "{}_{}".format(dup, name)
            
        yield new_name
        seen.add(new_name)
        
list(uniquify(change_dups))
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x_2',
#  'Car_x_2',
#  'Time',
#  'Gap',
#  'Laps_x_2',
#  'Pos_y_2',
#  'Car_y_2',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y_2',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
bahrain_dl = bahrain_dl.set_axis(['Pos_x',
 'Driver',
 'Car_x',
 'Time_x',
 'Gap_x',
 'Laps_x',
 'Pos_y',
 'Car_y',
 'Time_y',
 'Gap_y',
 'Laps_y',
 'Pos_x_2',
 'Car_x_2',
 'Time',
 'Gap',
 'Laps_x_2',
 'Pos_y_2',
 'Car_y_2',
 'Q1',
 'Q2',
 'Q3',
 'Laps_y_2',
 'Pos',
 'Car',
 'Laps',
 'Time/Retired',
 'PTS'], axis=1, inplace=False)

# %%
change_dups
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x',
#  'Car_x',
#  'Time',
#  'Gap',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
new_names = ['Pos1',
 'Driver1',
 'Car1',
 'Time1',
 'Gap1',
 'Laps1',
 'Pos2',
 'Car2',
 'Time2',
 'Gap2',
 'Laps2',
 'Pos3',
 'Car3',
 'Time3',
 'Gap3',
 'Laps3',
 'PosQ',
 'CarQ',
 'Q1_Q',
 'Q2_Q',
 'Q3_Q',
 'LapsQ',
 'PosRR',
 'CarRR',
 'LapsRR',
 'Time/Retired_RR',
 'PTS_RR']

# %%
bahrain_dl.columns = ['Pos1',
 'Driver1',
 'Car1',
 'Time1',
 'Gap1',
 'Laps1',
 'Pos2',
 'Car2',
 'Time2',
 'Gap2',
 'Laps2',
 'Pos3',
 'Car3',
 'Time3',
 'Gap3',
 'Laps3',
 'PosQ',
 'CarQ',
 'Q1_Q',
 'Q2_Q',
 'Q3_Q',
 'LapsQ',
 'PosRR',
 'CarRR',
 'LapsRR',
 'Time/Retired_RR',
 'PTS_RR']

# %%
bahrain_dl.drop(['Car2', 'Car3', 'CarQ', 'CarRR'], axis=1, inplace=True)

# %%
# bahrain_dl = bahrain_dl.fillna('n/a')

# %%
names_list = list(bahrain_dl.columns)

new_names_list = []

for names in names_list:
    names = 'bahrain_' + names
    new_names_list.append(names)
    
bahrain_dl.columns = new_names_list

# %%
bahrain_dl = bahrain_dl[~bahrain_dl['bahrain_Time/Retired_RR'].isin(['DNF'])]

# %%
pd.options.mode.chained_assignment = None  # default='warn'
bahrain_dl.drop(bahrain_dl.columns[[4, 5, 8, 9, 12, 13, 18, 20, 21]], axis=1, inplace=True)

# %%
bahrain_dl.drop(['bahrain_Time1', 'bahrain_Time2', 'bahrain_Time3'], axis=1, inplace=True)

# %%
def qualifying_values(race):
    race.iloc[:, 6] = race.iloc[:, 6].apply(lambda x: 1 if not pd.isnull(x) else 0)
    race.iloc[:, 7] = race.iloc[:, 7].apply(lambda x: 1 if not pd.isnull(x) else 0)
    race.iloc[:, 8] = race.iloc[:, 8].apply(lambda x: 1 if not pd.isnull(x) else 0)

# %%
qualifying_values(bahrain_dl)

# %%
bahrain_dl
# Out:
#     bahrain_Pos1           bahrain_Driver1               bahrain_Car1  \
# 0            7.0     Alexander  Albon  ALB      Red Bull Racing Honda
# 1           16.0  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 2            4.0        Carlos  Sainz  SAI            McLaren Renault
# 3           11.0     Charles  Leclerc  LEC                    Ferrari
# 4           10.0    Daniel  Ricciardo  RIC                    Renault
# 5           17.0        Daniil  Kvyat  KVY           AlphaTauri Honda
# 6            8.0        Esteban  Ocon  OCO                    Renault
# 7           15.0     Kevin  Magnussen  MAG               Haas Ferrari
# 9           18.0        Lando  Norris  NOR            McLaren Renault
# 10           1.0      Lewis  Hamilton  HAM                   Mercedes
# 11           6.0      Max  Verstappen  VER      Red Bull Racing Honda
# 12          19.0     Nicholas  Latifi  LAT          Williams Mercedes
# ...

# %%
bahrain_dl = bahrain_dl.drop(14)
bahrain_dl = bahrain_dl.drop(16)

# %%
bahrain_dl
# Out:
#     bahrain_Pos1           bahrain_Driver1               bahrain_Car1  \
# 0            7.0     Alexander  Albon  ALB      Red Bull Racing Honda
# 1           16.0  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 2            4.0        Carlos  Sainz  SAI            McLaren Renault
# 3           11.0     Charles  Leclerc  LEC                    Ferrari
# 4           10.0    Daniel  Ricciardo  RIC                    Renault
# 5           17.0        Daniil  Kvyat  KVY           AlphaTauri Honda
# 6            8.0        Esteban  Ocon  OCO                    Renault
# 7           15.0     Kevin  Magnussen  MAG               Haas Ferrari
# 9           18.0        Lando  Norris  NOR            McLaren Renault
# 10           1.0      Lewis  Hamilton  HAM                   Mercedes
# 11           6.0      Max  Verstappen  VER      Red Bull Racing Honda
# 12          19.0     Nicholas  Latifi  LAT          Williams Mercedes
# ...

# %%
# %store bahrain_dl
# Out:
# Stored 'bahrain_dl' (DataFrame)
