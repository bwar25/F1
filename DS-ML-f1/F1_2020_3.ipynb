# %%
# initial run through of project

# %%
# import necessary libraries

import pandas as pd

# %%
# scraping data 

titles = ['practice-1', 'practice-2', 'practice-3', 'qualifying', 'race-result']
url = 'https://www.formula1.com/en/results.html/2020/races/1047/hungary/{}.html'

for title in titles:
    urls = url.format(title)
    print(urls)
# Out:
# https://www.formula1.com/en/results.html/2020/races/1047/hungary/practice-1.html
# https://www.formula1.com/en/results.html/2020/races/1047/hungary/practice-2.html
# https://www.formula1.com/en/results.html/2020/races/1047/hungary/practice-3.html
# https://www.formula1.com/en/results.html/2020/races/1047/hungary/qualifying.html
# https://www.formula1.com/en/results.html/2020/races/1047/hungary/race-result.html

# %%
ThreeP1_2020 = 'https://www.formula1.com/en/results.html/2020/races/1047/hungary/practice-1.html'
ThreeP2_2020 = 'https://www.formula1.com/en/results.html/2020/races/1047/hungary/practice-2.html'
ThreeP3_2020 = 'https://www.formula1.com/en/results.html/2020/races/1047/hungary/practice-3.html'
ThreeQ_2020 = 'https://www.formula1.com/en/results.html/2020/races/1047/hungary/qualifying.html'
ThreeRR_2020 = 'https://www.formula1.com/en/results.html/2020/races/1047/hungary/race-result.html'

# %%
df_ThreeP1_2020 = pd.read_html(ThreeP1_2020, header=0)
df_ThreeP2_2020 = pd.read_html(ThreeP2_2020, header=0)
df_ThreeP3_2020 = pd.read_html(ThreeP3_2020, header=0)
df_ThreeQ_2020 = pd.read_html(ThreeQ_2020, header=0)
df_ThreeRR_2020 = pd.read_html(ThreeRR_2020, header=0)

df_ThreeP1_2020 = df_ThreeP1_2020[0]
df_ThreeP2_2020 = df_ThreeP2_2020[0]
df_ThreeP3_2020 = df_ThreeP3_2020[0]
df_ThreeQ_2020 = df_ThreeQ_2020[0]
df_ThreeRR_2020 = df_ThreeRR_2020[0]

# %%
df_ThreeP1_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_ThreeP2_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_ThreeP3_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_ThreeQ_2020.drop(['Unnamed: 0', 'Unnamed: 9', 'No'], axis=1, inplace=True)
df_ThreeRR_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)

# %%
# df_ThreeP1_2020 = df_ThreeP1_2020.fillna(0)
# df_ThreeP2_2020 = df_ThreeP2_2020.fillna(0)
# df_threeP3_2020 = df_ThreeP3_2020.fillna(0)

# %%
hungary_GP = [df_ThreeP1_2020, df_ThreeP2_2020, df_ThreeP3_2020, df_ThreeQ_2020, df_ThreeRR_2020]

# %%
hungary_GP_0 = hungary_GP[0]
hungary_GP_1 = hungary_GP[1]
hungary_GP_2 = hungary_GP[2]
hungary_GP_3 = hungary_GP[3]
hungary_GP_4 = hungary_GP[4]

# %%
hungary_allP = pd.concat([hungary_GP_0, hungary_GP_1, hungary_GP_2])
hungary_allP = hungary_allP.groupby('Driver').Pos.sum()
hungary_allP = pd.DataFrame(hungary_allP)
hungary_allP.rename(columns = {'Pos': 'Pos_Practice'}, inplace = True)

# %%
hungaryQ = hungary_GP_3.groupby('Driver').Pos.sum()
hungaryQ = pd.DataFrame(hungaryQ)
hungaryQ.rename(columns = {'Pos': 'Pos_Qualifying'}, inplace = True)

# %%
hungaryR = hungary_GP_4.groupby('Driver').Pos.sum()
hungaryR = pd.DataFrame(hungaryR)
hungaryR.rename(columns = {'Pos': 'Pos_Race'}, inplace = True)

# %%
hungary_end = pd.concat([hungary_allP, hungaryQ, hungaryR], axis=1)

# %%
hungary_GP_0.sort_values(by=['Driver'], inplace=True)
hungary_GP_1.sort_values(by=['Driver'], inplace=True)
hungary_GP_2.sort_values(by=['Driver'], inplace=True)
hungary_GP_3.sort_values(by=['Driver'], inplace=True)
hungary_GP_4.sort_values(by=['Driver'], inplace=True)

# %%
hungary_dl = pd.merge(hungary_GP_0, hungary_GP_1, on='Driver', how='outer')
hungary_dl = pd.merge(hungary_dl, hungary_GP_2, on='Driver', how='outer')
hungary_dl = pd.merge(hungary_dl, hungary_GP_3, on='Driver', how='outer')
hungary_dl = pd.merge(hungary_dl, hungary_GP_4, on='Driver', how='outer')

# %%
change_dups = hungary_dl.columns.values.tolist()
change_dups
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x',
#  'Car_x',
#  'Time',
#  'Gap',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
def uniquify(change_dups):
    seen = set()
    
    for dup in change_dups:
        name = 1
        new_name = dup
        
        while new_name in seen:
            name += 1
            new_name = "{}_{}".format(dup, name)
            
        yield new_name
        seen.add(new_name)
        
list(uniquify(change_dups))
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x_2',
#  'Car_x_2',
#  'Time',
#  'Gap',
#  'Laps_x_2',
#  'Pos_y_2',
#  'Car_y_2',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y_2',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
hungary_dl = hungary_dl.set_axis(['Pos_x',
 'Driver',
 'Car_x',
 'Time_x',
 'Gap_x',
 'Laps_x',
 'Pos_y',
 'Car_y',
 'Time_y',
 'Gap_y',
 'Laps_y',
 'Pos_x_2',
 'Car_x_2',
 'Time',
 'Gap',
 'Laps_x_2',
 'Pos_y_2',
 'Car_y_2',
 'Q1',
 'Q2',
 'Q3',
 'Laps_y_2',
 'Pos',
 'Car',
 'Laps',
 'Time/Retired',
 'PTS'], axis=1, inplace=False)

# %%
change_dups
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x',
#  'Car_x',
#  'Time',
#  'Gap',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
new_names = ['Pos1',
 'Driver1',
 'Car1',
 'Time1',
 'Gap1',
 'Laps1',
 'Pos2',
 'Car2',
 'Time2',
 'Gap2',
 'Laps2',
 'Pos3',
 'Car3',
 'Time3',
 'Gap3',
 'Laps3',
 'PosQ',
 'CarQ',
 'Q1_Q',
 'Q2_Q',
 'Q3_Q',
 'LapsQ',
 'PosRR',
 'CarRR',
 'LapsRR',
 'Time/Retired_RR',
 'PTS_RR']

# %%
hungary_dl.columns = ['Pos1',
 'Driver1',
 'Car1',
 'Time1',
 'Gap1',
 'Laps1',
 'Pos2',
 'Car2',
 'Time2',
 'Gap2',
 'Laps2',
 'Pos3',
 'Car3',
 'Time3',
 'Gap3',
 'Laps3',
 'PosQ',
 'CarQ',
 'Q1_Q',
 'Q2_Q',
 'Q3_Q',
 'LapsQ',
 'PosRR',
 'CarRR',
 'LapsRR',
 'Time/Retired_RR',
 'PTS_RR']

# %%
hungary_dl.drop(['Car2', 'Car3', 'CarQ', 'CarRR'], axis=1, inplace=True)

# %%
# hungary_dl = hungary_dl.fillna('n/a')

# %%
names_list = list(hungary_dl.columns)

new_names_list = []

for names in names_list:
    names = 'hungary_' + names
    new_names_list.append(names)
    
hungary_dl.columns = new_names_list

# %%
hungary_dl = hungary_dl[~hungary_dl['hungary_Time/Retired_RR'].isin(['DNF'])]

# %%
pd.options.mode.chained_assignment = None  # default='warn'
hungary_dl.drop(hungary_dl.columns[[4, 5, 8, 9, 12, 13, 18, 20, 21]], axis=1, inplace=True)

# %%
hungary_dl.drop(['hungary_Time1', 'hungary_Time2', 'hungary_Time3'], axis=1, inplace=True)

# %%
def qualifying_values(race):
    race.iloc[:, 6] = race.iloc[:, 6].apply(lambda x: 1 if not pd.isnull(x) else 0)
    race.iloc[:, 7] = race.iloc[:, 7].apply(lambda x: 1 if not pd.isnull(x) else 0)
    race.iloc[:, 8] = race.iloc[:, 8].apply(lambda x: 1 if not pd.isnull(x) else 0)

# %%
qualifying_values(hungary_dl)

# %%
hungary_dl = hungary_dl.drop(14)

# %%
hungary_dl['hungary_Pos1'] = hungary_dl['hungary_Pos1'].fillna(19.0)

# %%
hungary_dl['hungary_Car1'] = hungary_dl['hungary_Car1'].fillna('Alfa Romeo Racing Ferrari')

# %%
hungary_dl
# Out:
#     hungary_Pos1           hungary_Driver1               hungary_Car1  \
# 0           13.0     Alexander  Albon  ALB      Red Bull Racing Honda
# 1           17.0  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 2           11.0        Carlos  Sainz  SAI            McLaren Renault
# 3            7.0     Charles  Leclerc  LEC                    Ferrari
# 4            5.0    Daniel  Ricciardo  RIC                    Renault
# 5           16.0        Daniil  Kvyat  KVY           AlphaTauri Honda
# 6           10.0        Esteban  Ocon  OCO                    Renault
# 7           18.0      George  Russell  RUS          Williams Mercedes
# 8           12.0     Kevin  Magnussen  MAG               Haas Ferrari
# 9            4.0        Lance  Stroll  STR  Racing Point BWT Mercedes
# 10           9.0        Lando  Norris  NOR            McLaren Renault
# 11           1.0      Lewis  Hamilton  HAM                   Mercedes
# ...

# %%
# %store hungary_dl
# Out:
# Stored 'hungary_dl' (DataFrame)
