# %%
# initial run through of project

# %%
# import necessary libraries

import pandas as pd

# %%
# scraping data 

titles = ['practice-1', 'practice-2', 'practice-3', 'qualifying', 'race-result']
url = 'https://www.formula1.com/en/results.html/2020/races/1049/great-britain/{}.html'

for title in titles:
    urls = url.format(title)
    print(urls)
# Out:
# https://www.formula1.com/en/results.html/2020/races/1049/great-britain/practice-1.html
# https://www.formula1.com/en/results.html/2020/races/1049/great-britain/practice-2.html
# https://www.formula1.com/en/results.html/2020/races/1049/great-britain/practice-3.html
# https://www.formula1.com/en/results.html/2020/races/1049/great-britain/qualifying.html
# https://www.formula1.com/en/results.html/2020/races/1049/great-britain/race-result.html

# %%
FiveP1_2020 = 'https://www.formula1.com/en/results.html/2020/races/1049/great-britain/practice-1.html'
FiveP2_2020 = 'https://www.formula1.com/en/results.html/2020/races/1049/great-britain/practice-2.html'
FiveP3_2020 = 'https://www.formula1.com/en/results.html/2020/races/1049/great-britain/practice-3.html'
FiveQ_2020 = 'https://www.formula1.com/en/results.html/2020/races/1049/great-britain/qualifying.html'
FiveRR_2020 = 'https://www.formula1.com/en/results.html/2020/races/1049/great-britain/race-result.html'

# %%
df_FiveP1_2020 = pd.read_html(FiveP1_2020, header=0)
df_FiveP2_2020 = pd.read_html(FiveP2_2020, header=0)
df_FiveP3_2020 = pd.read_html(FiveP3_2020, header=0)
df_FiveQ_2020 = pd.read_html(FiveQ_2020, header=0)
df_FiveRR_2020 = pd.read_html(FiveRR_2020, header=0)

df_FiveP1_2020 = df_FiveP1_2020[0]
df_FiveP2_2020 = df_FiveP2_2020[0]
df_FiveP3_2020 = df_FiveP3_2020[0]
df_FiveQ_2020 = df_FiveQ_2020[0]
df_FiveRR_2020 = df_FiveRR_2020[0]

# %%
df_FiveP1_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_FiveP2_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_FiveP3_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)
df_FiveQ_2020.drop(['Unnamed: 0', 'Unnamed: 9', 'No'], axis=1, inplace=True)
df_FiveRR_2020.drop(['Unnamed: 0', 'Unnamed: 8', 'No'], axis=1, inplace=True)

# %%
# df_FiveP1_2020 = df_FiveP1_2020.fillna(0)
# df_FiveP2_2020 = df_FiveP2_2020.fillna(0)
# df_FiveP3_2020 = df_FiveP3_2020.fillna(0)

# %%
gb70_GP = [df_FiveP1_2020, df_FiveP2_2020, df_FiveP3_2020, df_FiveQ_2020, df_FiveRR_2020]

# %%
gb70_GP_0 = gb70_GP[0]
gb70_GP_1 = gb70_GP[1]
gb70_GP_2 = gb70_GP[2]
gb70_GP_3 = gb70_GP[3]
gb70_GP_4 = gb70_GP[4]

# %%
gb70_allP = pd.concat([gb70_GP_0, gb70_GP_1, gb70_GP_2])
gb70_allP = gb70_allP.groupby('Driver').Pos.sum()
gb70_allP = pd.DataFrame(gb70_allP)
gb70_allP.rename(columns = {'Pos': 'Pos_Practice'}, inplace = True)

# %%
gb70Q = gb70_GP_3.groupby('Driver').Pos.sum()
gb70Q = pd.DataFrame(gb70Q)
gb70Q.rename(columns = {'Pos': 'Pos_Qualifying'}, inplace = True)

# %%
gb70R = gb70_GP_4.groupby('Driver').Pos.sum()
gb70R = pd.DataFrame(gb70R)
gb70R.rename(columns = {'Pos': 'Pos_Race'}, inplace = True)

# %%
gb70_end = pd.concat([gb70_allP, gb70Q, gb70R], axis=1)

# %%
gb70_GP_0.sort_values(by=['Driver'], inplace=True)
gb70_GP_1.sort_values(by=['Driver'], inplace=True)
gb70_GP_2.sort_values(by=['Driver'], inplace=True)
gb70_GP_3.sort_values(by=['Driver'], inplace=True)
gb70_GP_4.sort_values(by=['Driver'], inplace=True)

# %%
gb70_dl = pd.merge(gb70_GP_0, gb70_GP_1, on='Driver', how='outer')
gb70_dl = pd.merge(gb70_dl, gb70_GP_2, on='Driver', how='outer')
gb70_dl = pd.merge(gb70_dl, gb70_GP_3, on='Driver', how='outer')
gb70_dl = pd.merge(gb70_dl, gb70_GP_4, on='Driver', how='outer')

# %%
change_dups = gb70_dl.columns.values.tolist()
change_dups
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x',
#  'Car_x',
#  'Time',
#  'Gap',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
def uniquify(change_dups):
    seen = set()
    
    for dup in change_dups:
        name = 1
        new_name = dup
        
        while new_name in seen:
            name += 1
            new_name = "{}_{}".format(dup, name)
            
        yield new_name
        seen.add(new_name)
        
list(uniquify(change_dups))
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x_2',
#  'Car_x_2',
#  'Time',
#  'Gap',
#  'Laps_x_2',
#  'Pos_y_2',
#  'Car_y_2',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y_2',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
gb70_dl = gb70_dl.set_axis(['Pos_x',
 'Driver',
 'Car_x',
 'Time_x',
 'Gap_x',
 'Laps_x',
 'Pos_y',
 'Car_y',
 'Time_y',
 'Gap_y',
 'Laps_y',
 'Pos_x_2',
 'Car_x_2',
 'Time',
 'Gap',
 'Laps_x_2',
 'Pos_y_2',
 'Car_y_2',
 'Q1',
 'Q2',
 'Q3',
 'Laps_y_2',
 'Pos',
 'Car',
 'Laps',
 'Time/Retired',
 'PTS'], axis=1, inplace=False)

# %%
change_dups
# Out:
# ['Pos_x',
#  'Driver',
#  'Car_x',
#  'Time_x',
#  'Gap_x',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Time_y',
#  'Gap_y',
#  'Laps_y',
#  'Pos_x',
#  'Car_x',
#  'Time',
#  'Gap',
#  'Laps_x',
#  'Pos_y',
#  'Car_y',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Laps_y',
#  'Pos',
#  'Car',
#  'Laps',
#  'Time/Retired',
#  'PTS']

# %%
new_names = ['Pos1',
 'Driver1',
 'Car1',
 'Time1',
 'Gap1',
 'Laps1',
 'Pos2',
 'Car2',
 'Time2',
 'Gap2',
 'Laps2',
 'Pos3',
 'Car3',
 'Time3',
 'Gap3',
 'Laps3',
 'PosQ',
 'CarQ',
 'Q1_Q',
 'Q2_Q',
 'Q3_Q',
 'LapsQ',
 'PosRR',
 'CarRR',
 'LapsRR',
 'Time/Retired_RR',
 'PTS_RR']

# %%
gb70_dl.columns = ['Pos1',
 'Driver1',
 'Car1',
 'Time1',
 'Gap1',
 'Laps1',
 'Pos2',
 'Car2',
 'Time2',
 'Gap2',
 'Laps2',
 'Pos3',
 'Car3',
 'Time3',
 'Gap3',
 'Laps3',
 'PosQ',
 'CarQ',
 'Q1_Q',
 'Q2_Q',
 'Q3_Q',
 'LapsQ',
 'PosRR',
 'CarRR',
 'LapsRR',
 'Time/Retired_RR',
 'PTS_RR']

# %%
gb70_dl.drop(['Car2', 'Car3', 'CarQ', 'CarRR'], axis=1, inplace=True)

# %%
# gb70_dl = gb70_dl.fillna('n/a')

# %%
names_list = list(gb70_dl.columns)

new_names_list = []

for names in names_list:
    names = 'gb70_' + names
    new_names_list.append(names)
    
gb70_dl.columns = new_names_list

# %%
gb70_dl = gb70_dl[~gb70_dl['gb70_Time/Retired_RR'].isin(['DNF'])]

# %%
pd.options.mode.chained_assignment = None  # default='warn'
gb70_dl.drop(gb70_dl.columns[[4, 5, 8, 9, 12, 13, 18, 20, 21]], axis=1, inplace=True)

# %%
gb70_dl.drop(['gb70_Time1', 'gb70_Time2', 'gb70_Time3'], axis=1, inplace=True)

# %%
def qualifying_values(race):
    race.iloc[:, 6] = race.iloc[:, 6].apply(lambda x: 1 if not pd.isnull(x) else 0)
    race.iloc[:, 7] = race.iloc[:, 7].apply(lambda x: 1 if not pd.isnull(x) else 0)
    race.iloc[:, 8] = race.iloc[:, 8].apply(lambda x: 1 if not pd.isnull(x) else 0)

# %%
qualifying_values(gb70_dl)

# %%
gb70_dl = gb70_dl.drop(16)

# %%
gb70_dl['gb70_Pos1'] = gb70_dl['gb70_Pos1'].fillna(19.0)

# %%
gb70_dl['gb70_Car1'] = gb70_dl['gb70_Car1'].fillna('Alfa Romeo Racing Ferrari')

# %%
gb70_dl
# Out:
#     gb70_Pos1              gb70_Driver1                  gb70_Car1  gb70_Pos2  \
# 0         6.0     Alexander  Albon  ALB      Red Bull Racing Honda       11.0
# 1        14.0        Carlos  Sainz  SAI            McLaren Renault        9.0
# 2         5.0     Charles  Leclerc  LEC                    Ferrari        7.0
# 3        17.0    Daniel  Ricciardo  RIC                    Renault        3.0
# 4         9.0        Daniil  Kvyat  KVY           AlphaTauri Honda       12.0
# 5        10.0        Esteban  Ocon  OCO                    Renault       10.0
# 6        15.0      George  Russell  RUS          Williams Mercedes       16.0
# 8        18.0      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari       17.0
# 9         8.0        Lance  Stroll  STR  Racing Point BWT Mercedes        5.0
# 10       12.0        Lando  Norris  NOR            McLaren Renault        8.0
# 11        2.0      Lewis  Hamilton  HAM                   Mercedes        1.0
# ...

# %%
# %store gb70_dl
# Out:
# Stored 'gb70_dl' (DataFrame)
